# %%
import pandas as pd
# Out:
# /home/Chris/anaconda3/lib/python3.9/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /home/Chris/anaconda3/lib/python3.9/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.2' currently installed).
#   from pandas.core import (

# %%
# !ls
# Out:
# 2006_crime_incidents.csv.gz  2015_crime_incidents.txt
# 2006_crime_incidents.txt     2016_crime_incidents.csv.gz
# 2007_crime_incidents.csv.gz  2016_crime_incidents.txt
# 2007_crime_incidents.txt     2017_crime_incidents.csv.gz
# 2008_crime_incidents.csv.gz  2017_crime_incidents.txt
# 2008_crime_incidents.txt     2018_crime_incidents.csv.gz
# 2009_crime_incidents.csv.gz  2018_crime_incidents.txt
# 2009_crime_incidents.txt     2019_crime_incidents.csv.gz
# 2010_crime_incidents.csv.gz  2019_crime_incidents.txt
# 2010_crime_incidents.txt     2020_crime_incidents.csv.gz
# 2011_crime_incidents.csv.gz  2020_crime_incidents.txt
# 2011_crime_incidents.txt     2021_crime_incidents.csv.gz
# 2012_crime_incidents.csv.gz  2021_crime_incidents.txt
# 2012_crime_incidents.txt     2022_crime_incidents.csv.gz
# 2013_crime_incidents.csv.gz  2022_crime_incidents.txt
# 2013_crime_incidents.txt     2023_crime_incidents.csv.gz
# 2014_crime_incidents.csv.gz  2023_crime_incidents.txt
# ...

# %%
df = pd.read_csv('2008_crime_incidents.txt')

# %%
df.sort_values('dispatch_date')
# Out:
#         objectid  dc_dist psa      dispatch_date_time dispatch_date  \
# 63613    1075556       19   N  2008-01-01 04:53:00+00    2007-12-31
# 74578    1080287        2   M  2008-01-01 01:35:00+00    2007-12-31
# 86764    1665338       19   R  2008-01-01 02:17:00+00    2007-12-31
# 25546     745906       24   I  2008-01-01 01:30:00+00    2007-12-31
# 86884    1671334       25   L  2008-01-01 01:32:00+00    2007-12-31
# ...          ...      ...  ..                     ...           ...
# 67916    1056564       22   N  2008-12-31 13:34:00+00    2008-12-31
# 85627    1629523       14   N  2008-12-31 06:08:00+00    2008-12-31
# 28350     839837       24   P  2008-12-31 21:52:00+00    2008-12-31
# 211673  14233053       39   H  2008-12-31 05:00:00+00    2008-12-31
# 201536   2906536       23   J  2008-12-31 18:56:00+00    2008-12-31
#
#        dispatch_time  hour        dc_key             location_block  \
# 63613       23:53:00  23.0  2.008190e+11       5200 BLOCK HARLAN ST
# ...
