# %%
import pandas as pd
# Out:
# /home/Chris/anaconda3/lib/python3.9/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /home/Chris/anaconda3/lib/python3.9/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.2' currently installed).
#   from pandas.core import (

# %%
df = pd.read_csv("2023_crime_incidents.txt")
df.head()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169017 entries, 0 to 169016
# Data columns (total 18 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   the_geom              162005 non-null  object
#  1   cartodb_id            169017 non-null  int64
#  2   the_geom_webmercator  161952 non-null  object
#  3   objectid              169017 non-null  int64
#  4   dc_dist               169017 non-null  int64
#  5   psa                   168954 non-null  object
#  6   dispatch_date_time    169017 non-null  object
#  7   dispatch_date         169017 non-null  object
#  8   dispatch_time         169017 non-null  object
#  9   hour                  68398 non-null   float64
#  10  dc_key                169017 non-null  float64
#  11  location_block        168967 non-null  object
#  12  ucr_general           169017 non-null  int64
#  13  text_general_code     169017 non-null  object
# ...

# %%
df.tail(20)
# Out:
#                                                  the_geom  cartodb_id  \
# 168997  0101000020E61000009B5090F1CBC752C04086F1470FFF...     3227210
# 168998  0101000020E6100000B1B4BE0EFDCE52C06E7CF50AEEFC...     3227211
# 168999  0101000020E610000089FF852F1DCF52C02FCD6383BBF8...     3227212
# 169000  0101000020E61000008EE19802A5CA52C031F22EEE71F9...     3227213
# 169001  0101000020E61000000FDC58BB33CB52C047CE3E6652FA...     3227214
# 169002  0101000020E61000001B8FC65F62C752C0D5EFDB738DFF...     3227215
# 169003  0101000020E61000002C01212746C952C031E7BE412005...     3227216
# 169004  0101000020E6100000D4AF3A93F2CB52C0078B37F072FE...     3227217
# 169005  0101000020E61000003F83761C79C952C04DF910540D01...     3227218
# 169006  0101000020E61000007F3AD4A5F5C452C0BB6F4AB3D801...     3227219
# 169007  0101000020E6100000FA36713063C752C0A3D34E281F06...     3227220
# 169008  0101000020E61000007B6DD32BA7C252C0E9ADEC489607...     3227221
# ...

# %%
df.sort_values(by="dispatch_date", ascending=False)
# Out:
#                                                  the_geom  cartodb_id  \
# 164256  0101000020E6100000A08CAF45A4CA52C0E2063A62C6FB...     3213663
# 158709  0101000020E6100000DA162B8B3EC852C02770E3FD55FF...     3187741
# 156715  0101000020E6100000E6F4CCFD5BC852C0DD48D1B12000...     3174305
# 162693  0101000020E6100000E93613995AC952C09A9359B552F6...     3210401
# 159232  0101000020E6100000966D5465A7C152C086968E9CF904...     3191431
# ...                                                   ...         ...
# 5237    0101000020E610000004EE929B55CB52C0A0694FEA4701...      185963
# 5474    0101000020E6100000B0B2AEB8D5C352C06F79F6A6B302...      190892
# 21629   0101000020E6100000723D44822DCA52C0144031B2E4FE...     1141056
# 22565   0101000020E6100000F93C143F25CF52C0E9C1D5E8F2F9...     1158683
# 22118   0101000020E610000050BB8884A9C952C0D767CEFA9400...     1149940
#
#                                      the_geom_webmercator  objectid  dc_dist  \
# ...
