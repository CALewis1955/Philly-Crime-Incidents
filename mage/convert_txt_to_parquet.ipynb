# %%
import pandas as pd

# %%
import os

# %%
! pwd
# Out:
# /home/Chris/mage/data/csv

# %%
! ls
# Out:
# 2006_crime_incidents.csv.gz  2014_crime_incidents.csv.gz
# 2007_crime_incidents.csv.gz  2015_crime_incidents.csv.gz
# 2008_crime_incidents.csv.gz  2016_crime_incidents.csv.gz
# 2009_crime_incidents.csv.gz  2017_crime_incidents.csv.gz
# 2010_crime_incidents.csv.gz  2018_crime_incidents.csv.gz
# 2011_crime_incidents.csv.gz  2019_crime_incidents.csv.gz
# 2012_crime_incidents.csv.gz  Untitled.ipynb
# 2013_crime_incidents.csv.gz  data

# %%
# !touch 2006_crime_incidents.txt

# %%
! cp 2006_crime_incidents.csv.gz 2006_crime_incidents.txt

# %%
df = pd.read_csv('2006_crime_incidents.txt')

# %%
df.head()
# Out:
#    objectid  dc_dist psa      dispatch_date_time dispatch_date dispatch_time  \
# 0       478       24   O  2006-09-06 09:27:00+00    2006-09-06      05:27:00
# 1       490        9   B  2006-07-08 21:47:00+00    2006-07-08      17:47:00
# 2       497       25   K  2006-07-26 13:39:00+00    2006-07-26      09:39:00
# 3       526       24   P  2006-08-07 11:29:00+00    2006-08-07      07:29:00
# 4       533       25   J  2006-06-01 04:02:00+00    2006-06-01      00:02:00
#
#    hour        dc_key        location_block  ucr_general  \
# 0     5  2.006241e+11       3500 BLOCK G ST          400
# 1    17  2.006090e+11   400 BLOCK S 18TH ST          500
# 2     9  2.006251e+11  3500 BLOCK N 07TH ST          600
# 3     7  2.006241e+11  0 BLOCK E SELTZER ST          600
# 4     0  2.006251e+11  3100 BLOCK N 06TH ST          300
#
#                text_general_code    point_x    point_y        lat        lng
# 0  Aggravated Assault No Firearm -75.114318  40.002079  40.002079 -75.114318
# ...

# %%
print([col for col in df.columns])
# Out:
# ['objectid', 'dc_dist', 'psa', 'dispatch_date_time', 'dispatch_date', 'dispatch_time', 'hour', 'dc_key', 'location_block', 'ucr_general', 'text_general_code', 'point_x', 'point_y', 'lat', 'lng']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 223266 entries, 0 to 223265
# Data columns (total 15 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   objectid            223266 non-null  int64
#  1   dc_dist             223266 non-null  int64
#  2   psa                 223259 non-null  object
#  3   dispatch_date_time  223266 non-null  object
#  4   dispatch_date       223266 non-null  object
#  5   dispatch_time       223266 non-null  object
#  6   hour                223266 non-null  int64
#  7   dc_key              223266 non-null  float64
#  8   location_block      223266 non-null  object
#  9   ucr_general         223266 non-null  int64
#  10  text_general_code   223266 non-null  object
#  11  point_x             217675 non-null  float64
#  12  point_y             217675 non-null  float64
#  13  lat                 217675 non-null  float64
#  14  lng                 217675 non-null  float64
# ...

# %%
df1 = df.convert_dtypes()

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 223266 entries, 0 to 223265
# Data columns (total 15 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   objectid            223266 non-null  Int64
#  1   dc_dist             223266 non-null  Int64
#  2   psa                 223259 non-null  string
#  3   dispatch_date_time  223266 non-null  string
#  4   dispatch_date       223266 non-null  string
#  5   dispatch_time       223266 non-null  string
#  6   hour                223266 non-null  Int64
#  7   dc_key              223266 non-null  Int64
#  8   location_block      223266 non-null  string
#  9   ucr_general         223266 non-null  Int64
#  10  text_general_code   223266 non-null  string
#  11  point_x             217675 non-null  Float64
#  12  point_y             217675 non-null  Float64
#  13  lat                 217675 non-null  Float64
#  14  lng                 217675 non-null  Float64
# ...

# %%
df1.head()
# Out:
#    objectid  dc_dist psa      dispatch_date_time dispatch_date dispatch_time  \
# 0       478       24   O  2006-09-06 09:27:00+00    2006-09-06      05:27:00
# 1       490        9   B  2006-07-08 21:47:00+00    2006-07-08      17:47:00
# 2       497       25   K  2006-07-26 13:39:00+00    2006-07-26      09:39:00
# 3       526       24   P  2006-08-07 11:29:00+00    2006-08-07      07:29:00
# 4       533       25   J  2006-06-01 04:02:00+00    2006-06-01      00:02:00
#
#    hour        dc_key        location_block  ucr_general  \
# 0     5  200624082152       3500 BLOCK G ST          400
# 1    17  200609034275   400 BLOCK S 18TH ST          500
# 2     9  200625078611  3500 BLOCK N 07TH ST          600
# 3     7  200624072426  0 BLOCK E SELTZER ST          600
# 4     0  200625057091  3100 BLOCK N 06TH ST          300
#
#                text_general_code    point_x    point_y        lat        lng
# 0  Aggravated Assault No Firearm -75.114318  40.002079  40.002079 -75.114318
# ...

# %%
df1['dispatch_date_time'] = pd.to_datetime(df['dispatch_date_time'])

# %%
df1['dispatch_date'] = pd.to_datetime(df['dispatch_date'])

# %%
df1['dispatch_time'] = pd.to_datetime(df['dispatch_time'])

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 223266 entries, 0 to 223265
# Data columns (total 15 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   objectid            223266 non-null  Int64
#  1   dc_dist             223266 non-null  Int64
#  2   psa                 223259 non-null  string
#  3   dispatch_date_time  223266 non-null  datetime64[ns, UTC]
#  4   dispatch_date       223266 non-null  datetime64[ns]
#  5   dispatch_time       223266 non-null  datetime64[ns]
#  6   hour                223266 non-null  Int64
#  7   dc_key              223266 non-null  Int64
#  8   location_block      223266 non-null  string
#  9   ucr_general         223266 non-null  Int64
#  10  text_general_code   223266 non-null  string
#  11  point_x             217675 non-null  Float64
#  12  point_y             217675 non-null  Float64
#  13  lat                 217675 non-null  Float64
# ...

# %%
import pyarrow as pa

# %%
! pip install fastparquet
# Out:
# ...
#      |████████████████████████████████| 1.7 MB 1.6 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 13.0 MB 66.4 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 1.9 MB 51.1 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 18.2 MB 49.5 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 345 kB 74.5 MB/s eta 0:00:01
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.20.3
#     Uninstalling numpy-1.20.3:
#       Successfully uninstalled numpy-1.20.3
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.3.4
#     Uninstalling pandas-1.3.4:
#       Successfully uninstalled pandas-1.3.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# daal4py 2021.3.0 requires daal==2021.2.3, which is not installed.
# ...

# %%
import fastparquet
from fastparquet import ParquetFile

# %%
df1.to_parquet('df.parquet.gzip', engine='auto', compression='gzip')

# %%
! ls
# Out:
# 2006_crime_incidents.csv.gz  2014_crime_incidents.csv.gz
# 2006_crime_incidents.txt     2015_crime_incidents.csv.gz
# 2007_crime_incidents.csv.gz  2016_crime_incidents.csv.gz
# 2008_crime_incidents.csv.gz  2017_crime_incidents.csv.gz
# 2009_crime_incidents.csv.gz  2018_crime_incidents.csv.gz
# 2010_crime_incidents.csv.gz  2019_crime_incidents.csv.gz
# 2011_crime_incidents.csv.gz  Untitled.ipynb
# 2012_crime_incidents.csv.gz  data
# 2013_crime_incidents.csv.gz  df.parquet.gzip

# %%
! pip install pyarrow
# Out:
# ...
#      |████████████████████████████████| 38.3 MB 1.6 MB/s eta 0:00:01
# ...

# %%
import pyarrow.parquet as pq

# %%
table = pq.read_table('df.parquet.gzip')

# %%
pd.read_parquet('df.parquet.gzip')
# Out:
#         objectid  dc_dist psa        dispatch_date_time dispatch_date  \
# 0            478       24   O 2006-09-06 09:27:00+00:00    2006-09-06
# 1            490        9   B 2006-07-08 21:47:00+00:00    2006-07-08
# 2            497       25   K 2006-07-26 13:39:00+00:00    2006-07-26
# 3            526       24   P 2006-08-07 11:29:00+00:00    2006-08-07
# 4            533       25   J 2006-06-01 04:02:00+00:00    2006-06-01
# ...          ...      ...  ..                       ...           ...
# 223261  14236313       12   J 2006-02-05 05:00:00+00:00    2006-02-05
# 223262  14236321       14   F 2006-09-24 04:00:00+00:00    2006-09-24
# 223263  14236339       19   R 2006-05-03 04:00:00+00:00    2006-05-03
# 223264  14236076       12   L 2006-11-11 05:00:00+00:00    2006-11-11
# 223265  14236088       19   L 2006-03-18 05:00:00+00:00    2006-03-18
#
#              dispatch_time  hour        dc_key               location_block  \
# ...
