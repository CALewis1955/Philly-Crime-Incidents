# %%
import pandas as pd

# %%
! ls ./data/raw/csv
# Out:
# 2006_crime_incidents.csv.gz  2015_crime_incidents.csv.gz
# 2007_crime_incidents.csv.gz  2016_crime_incidents.csv.gz
# 2008_crime_incidents.csv.gz  2017_crime_incidents.csv.gz
# 2009_crime_incidents.csv.gz  2018_crime_incidents.csv.gz
# 2010_crime_incidents.csv.gz  2019_crime_incidents.csv.gz
# 2011_crime_incidents.csv.gz  2020_crime_incidents.csv.gz
# 2012_crime_incidents.csv.gz  2021_crime_incidents.csv.gz
# 2013_crime_incidents.csv.gz  2022_crime_incidents.csv.gz
# 2014_crime_incidents.csv.gz  2023_crime_incidents.csv.gz

# %% [markdown]
# #### I tried to read the files into pandas as zipped .gz files but got an error.  It turns out the files are simple text files.  To read them into Pandas, I renamed them as txt files and then performed a "read_csv."

# %%
# !cp ./data/raw/csv/2023_crime_incidents.csv.gz crime_incidents.txt

# %%
# !ls
# Out:
# README.md  Untitled.ipynb  crime_incidents.txt	data  scripts

# %%
df = pd.read_csv('crime_incidents.txt', nrows=1000)

# %%
df.head()
# Out:
#                                             the_geom  cartodb_id  \
# 0  0101000020E6100000A51C8299A5C752C006342AD3DCFF...           2
# 1  0101000020E6100000F9245E3B64CC52C0B7195D940FF6...           4
# 2  0101000020E6100000118A52E7F6C052C0CFF41263190C...           7
# 3  0101000020E6100000E1F9FB7B5FC552C0159C0B6D4A02...         123
# 4  0101000020E6100000D1CCD5875CCA52C014B723FFC005...         126
#
#                                 the_geom_webmercator  objectid  dc_dist  psa  \
# 0  0101000020110F0000F80DE2A145E65FC1E5EC7592BE8F...       114       25  3.0
# 1  0101000020110F00000426B7CE54EE5FC1C5E06D37E284...       116        1  1.0
# 2  0101000020110F00006728CED7EBDA5FC169DB64F8519D...       119        8  2.0
# 3  0101000020110F00009D28D4D968E25FC13CD5C3D06F92...        96       15  1.0
# 4  0101000020110F00002F28E30AE2EA5FC10090A3314796...        99       14  1.0
#
#        dispatch_date_time dispatch_date dispatch_time  hour        dc_key  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   the_geom              1000 non-null   object
#  1   cartodb_id            1000 non-null   int64
#  2   the_geom_webmercator  1000 non-null   object
#  3   objectid              1000 non-null   int64
#  4   dc_dist               1000 non-null   int64
#  5   psa                   999 non-null    float64
#  6   dispatch_date_time    1000 non-null   object
#  7   dispatch_date         1000 non-null   object
#  8   dispatch_time         1000 non-null   object
#  9   hour                  1000 non-null   int64
#  10  dc_key                1000 non-null   float64
#  11  location_block        1000 non-null   object
#  12  ucr_general           1000 non-null   int64
#  13  text_general_code     1000 non-null   object
#  14  point_x               1000 non-null   float64
# ...

# %%
# !cp ./data/raw/csv/2006_crime_incidents.csv.gz crime_incidents_2006.txt

# %%
df2 = pd.read_csv('crime_incidents_2006.txt', nrows=1001)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1001 entries, 0 to 1000
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   objectid            1001 non-null   int64
#  1   dc_dist             1001 non-null   int64
#  2   psa                 1001 non-null   object
#  3   dispatch_date_time  1001 non-null   object
#  4   dispatch_date       1001 non-null   object
#  5   dispatch_time       1001 non-null   object
#  6   hour                1001 non-null   int64
#  7   dc_key              1001 non-null   float64
#  8   location_block      1001 non-null   object
#  9   ucr_general         1001 non-null   int64
#  10  text_general_code   1001 non-null   object
#  11  point_x             1001 non-null   float64
#  12  point_y             1001 non-null   float64
#  13  lat                 1001 non-null   float64
#  14  lng                 1001 non-null   float64
# ...

# %% [markdown]
# #### The schema for the post-2000 files is different.  They add three new geom fields at the start.

# %%
df['psa'].unique()
# Out:
# array([ 3.,  1.,  2.,  4., nan])

# %%
sorted(df['dc_dist'].unique())
# Out:
# [1, 2, 3, 5, 6, 7, 8, 9, 12, 14, 15, 16, 17, 18, 19, 22, 24, 25, 26, 35, 39]

# %%
sorted(df2['dc_dist'].unique())
# Out:
# [1,
#  2,
#  3,
#  4,
#  5,
#  6,
#  7,
#  8,
#  9,
#  12,
#  14,
#  15,
#  16,
#  17,
#  18,
#  19,
#  22,
#  23,
#  24,
#  25,
#  26,
#  35,
#  39,
#  92]

# %%
sorted(df.dispatch_date.unique())
# Out:
# ['2023-02-06',
#  '2023-02-16',
#  '2023-02-19',
#  '2023-02-22',
#  '2023-02-26',
#  '2023-03-06',
#  '2023-03-11',
#  '2023-03-12',
#  '2023-03-24',
#  '2023-03-25',
#  '2023-04-12']

# %% [markdown]
# #### We need to check whether the data contains all days of the year.

# %%
sorted(df.location_block.unique())
# Out:
# ['0 BLOCK BONNIE GELLMAN CT',
#  '0 BLOCK CRESCENT DR',
#  '0 BLOCK FRANKLIN MILLS BLVD',
#  '0 BLOCK MEEHAN AV',
#  '0 BLOCK MIFFLIN ST',
#  '0 BLOCK N 12TH ST',
#  '0 BLOCK N 19TH ST',
#  '0 BLOCK N 50TH ST',
#  '0 BLOCK N 9TH ST',
#  '0 BLOCK N CONESTOGA ST',
#  '0 BLOCK N FRAZIER ST',
#  '0 BLOCK NOBLE ST',
#  '0 BLOCK PENN BLVD',
#  '0 BLOCK S 13TH ST',
#  '0 BLOCK S FRONT ST 504',
#  '0 BLOCK S SALFORD ST',
#  '0 BLOCK SNYDER AV',
#  '0 BLOCK W PENN ST',
#  '0 BLOCK W ROCKLAND ST',
#  '0 BLOCK W SEYMOUR ST',
#  '1&6&2023 12:00:00 Am1&6&2023 12:00:00 Am',
#  '100 BLOCK E ALLEGHENY AV',
#  '100 BLOCK E INDIANA AV',
#  '100 BLOCK E OLNEY AV',
#  '100 BLOCK E Olney Ave',
#  '100 BLOCK E SHARPNACK ST',
#  '100 BLOCK E WASHINGTON LA',
#  '100 BLOCK FAIRMOUNT AV',
#  '100 BLOCK FRANKLIN MILLS BLVD',
#  '100 BLOCK LOMBARD ST 1',
#  '100 BLOCK N 18TH ST',
#  '100 BLOCK N 33RD ST',
#  '100 BLOCK N 3RD ST',
#  '100 BLOCK N 63RD ST',
#  '100 BLOCK S 12TH ST',
#  '100 BLOCK S 19TH ST',
# ...

# %%
sorted(df.text_general_code.unique())
# Out:
# ['Aggravated Assault Firearm',
#  'Aggravated Assault No Firearm',
#  'Burglary Non-Residential',
#  'Burglary Residential',
#  'Rape',
#  'Robbery Firearm',
#  'Robbery No Firearm',
#  'Theft from Vehicle',
#  'Thefts']

# %%
sorted(df2.text_general_code.unique())
# Out:
# ['Aggravated Assault Firearm',
#  'Aggravated Assault No Firearm',
#  'Burglary Non-Residential',
#  'Burglary Residential',
#  'Rape',
#  'Robbery Firearm',
#  'Robbery No Firearm',
#  'Theft from Vehicle',
#  'Thefts']

# %%
sorted(df.ucr_general.unique())
# Out:
# [200, 300, 400, 500, 600]

# %%
sorted(df2.ucr_general.unique())
# Out:
# [200, 300, 400, 500, 600]

# %%
df3 = pd.read_csv('crime_incidents.txt')

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169017 entries, 0 to 169016
# Data columns (total 18 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   the_geom              162005 non-null  object
#  1   cartodb_id            169017 non-null  int64
#  2   the_geom_webmercator  161952 non-null  object
#  3   objectid              169017 non-null  int64
#  4   dc_dist               169017 non-null  int64
#  5   psa                   168954 non-null  object
#  6   dispatch_date_time    169017 non-null  object
#  7   dispatch_date         169017 non-null  object
#  8   dispatch_time         169017 non-null  object
#  9   hour                  68398 non-null   float64
#  10  dc_key                169017 non-null  float64
#  11  location_block        168967 non-null  object
#  12  ucr_general           169017 non-null  int64
#  13  text_general_code     169017 non-null  object
# ...

# %%
sorted(df3.ucr_general.unique())
# Out:
# [100,
#  200,
#  300,
#  400,
#  500,
#  600,
#  700,
#  800,
#  900,
#  1000,
#  1100,
#  1200,
#  1300,
#  1400,
#  1500,
#  1600,
#  1700,
#  1800,
#  1900,
#  2000,
#  2100,
#  2200,
#  2300,
#  2400,
#  2500,
#  2600]

# %% [markdown]
# #### The 2023 data are incomplete and contain information for only 11 days.

# %%
df.dispatch_date.unique()
# Out:
# array(['2023-03-11', '2023-02-26', '2023-04-12', '2023-02-22',
#        '2023-03-12', '2023-02-19', '2023-03-06', '2023-02-06',
#        '2023-03-24', '2023-03-25', '2023-02-16'], dtype=object)

# %%
df4 = pd.read_csv('crime_incidents_2006.txt')

# %%
df4.dispatch_date.unique()
# Out:
# array(['2006-09-06', '2006-07-08', '2006-07-26', '2006-08-07',
#        '2006-06-01', '2006-11-19', '2006-10-02', '2006-07-10',
#        '2006-09-22', '2006-08-15', '2006-07-20', '2006-07-04',
#        '2006-11-10', '2006-06-27', '2006-12-01', '2006-11-16',
#        '2006-10-06', '2006-11-27', '2006-08-27', '2006-10-05',
#        '2006-11-24', '2006-07-11', '2006-10-11', '2006-10-19',
#        '2006-07-19', '2006-07-25', '2006-09-05', '2006-08-01',
#        '2006-08-18', '2006-08-22', '2006-11-18', '2006-08-28',
#        '2006-08-21', '2006-12-07', '2006-12-20', '2006-07-29',
#        '2006-12-10', '2006-09-04', '2006-06-06', '2006-08-23',
#        '2006-09-27', '2006-10-16', '2006-09-28', '2006-10-29',
#        '2006-09-25', '2006-08-25', '2006-07-15', '2006-09-30',
#        '2006-12-18', '2006-11-28', '2006-10-09', '2006-06-22',
#        '2006-07-22', '2006-07-14', '2006-10-14', '2006-09-14',
#        '2006-06-21', '2006-08-16', '2006-07-17', '2006-11-21',
# ...

# %%
len(df4.dispatch_date.unique())
# Out:
# 365

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 223266 entries, 0 to 223265
# Data columns (total 15 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   objectid            223266 non-null  int64
#  1   dc_dist             223266 non-null  int64
#  2   psa                 223259 non-null  object
#  3   dispatch_date_time  223266 non-null  object
#  4   dispatch_date       223266 non-null  object
#  5   dispatch_time       223266 non-null  object
#  6   hour                223266 non-null  int64
#  7   dc_key              223266 non-null  float64
#  8   location_block      223266 non-null  object
#  9   ucr_general         223266 non-null  int64
#  10  text_general_code   223266 non-null  object
#  11  point_x             217675 non-null  float64
#  12  point_y             217675 non-null  float64
#  13  lat                 217675 non-null  float64
#  14  lng                 217675 non-null  float64
# ...

# %%
sorted(df4.text_general_code.unique())
# Out:
# ['Aggravated Assault Firearm',
#  'Aggravated Assault No Firearm',
#  'All Other Offenses',
#  'Arson',
#  'Burglary Non-Residential',
#  'Burglary Residential',
#  'DRIVING UNDER THE INFLUENCE',
#  'Disorderly Conduct',
#  'Embezzlement',
#  'Forgery and Counterfeiting',
#  'Fraud',
#  'Gambling Violations',
#  'Homicide - Criminal',
#  'Homicide - Justifiable',
#  'Liquor Law Violations',
#  'Motor Vehicle Theft',
#  'Narcotic / Drug Law Violations',
#  'Offenses Against Family and Children',
#  'Other Assaults',
#  'Other Sex Offenses (Not Commercialized)',
#  'Prostitution and Commercialized Vice',
#  'Public Drunkenness',
#  'Rape',
#  'Receiving Stolen Property',
#  'Robbery Firearm',
#  'Robbery No Firearm',
#  'Theft from Vehicle',
#  'Thefts',
#  'Vagrancy/Loitering',
#  'Vandalism/Criminal Mischief',
#  'Weapon Violations']

# %%
df4[df4.text_general_code == 'Homicide - Criminal']
# Out:
#         objectid  dc_dist  psa      dispatch_date_time dispatch_date  \
# 222861  14078068       12    D  2006-07-03 04:00:00+00    2006-07-03
# 222862  14078133        8    O  2006-04-08 04:00:00+00    2006-04-08
# 222863  14078141        2    N  2006-11-24 05:00:00+00    2006-11-24
# 222864  14078197       22    D  2006-12-28 05:00:00+00    2006-12-28
# 222865  14078249        8    A  2006-09-09 04:00:00+00    2006-09-09
# ...          ...      ...  ...                     ...           ...
# 223261  14081982       35  NaN  2006-09-25 04:00:00+00    2006-09-25
# 223262  14081983       39    D  2006-09-27 04:00:00+00    2006-09-27
# 223263  14081984       39    F  2006-10-02 04:00:00+00    2006-10-02
# 223264  14081985        1    J  2006-10-03 04:00:00+00    2006-10-03
# 223265  14081986       12    L  2006-10-07 04:00:00+00    2006-10-07
#
#        dispatch_time  hour        dc_key                location_block  \
# ...
